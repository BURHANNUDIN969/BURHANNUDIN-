# %% [markdown]
# <a href="https://colab.research.google.com/github/BURHANNUDIN969/BURHANNUDIN-/blob/main/UDINPRATIKUMK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya

nama = "burhannudin"
umur = 21
tanggal_lahir = "19-04-2005"
jurusan = "RPE"
alamat = "sagulung sumber sari blok c11 no 22"
prodi = "Rekayasa pembangkit energi"
semester = 3
matakuliah = "pemogramman dasar"
status_lulus = False


print(nama)
print(umur)
print(tanggal_lahir)
print(jurusan)
print(alamat)
print(prodi)
print(semester)
print(matakuliah)
print(status_lulus)
# Out:
# burhannudin
# 21
# 19-04-2005
# RPE
# sagulung sumber sari blok c11 no 22
# Rekayasa pembangkit energi
# 3
# pemogramman dasar
# False
