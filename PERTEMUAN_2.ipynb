# %% [markdown]
# <a href="https://colab.research.google.com/github/BURHANNUDIN969/BURHANNUDIN-/blob/main/PERTEMUAN_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jawaban Latihan 1
tegangan = 18
arus = 6
jenis_sel = "Monocrystalline"

print(tegangan)
print(arus)
print(jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
# Jawaban Latihan 2
jumlah_resistor = 10                  # int
kapasitansi = 4.7                     # float
is_aktif = True                       # bool
nama_komponen = "Kapasitor"           # str

print(jumlah_resistor, type(jumlah_resistor))
print(kapasitansi, type(kapasitansi))
print(is_aktif, type(is_aktif))
print(nama_komponen, type(nama_komponen))
# Out:
# 10 <class 'int'>
# 4.7 <class 'float'>
# True <class 'bool'>
# Kapasitor <class 'str'>

# %%
# Jawaban Latihan 3
nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroperasi, type(sedang_beroperasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
# Jawaban Latihan 4
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

# (a) cetak pembacaan pertama dan terakhir memakai indeks
print("Pembacaan pertama:", tegangan_harian[0])
print("Pembacaan terakhir:", tegangan_harian[-1])

# (b) tambahkan satu pembacaan baru 222.0 dengan append()
tegangan_harian.append(222.0)

# (c) cetak jumlah total data dengan len()
print("Jumlah total data:", len(tegangan_harian))
# Out:
# Pembacaan pertama: 217.5
# Pembacaan terakhir: 216.9
# Jumlah total data: 7

# %%
# Jawaban Latihan 5
motor_listrik = {
    "nama": "Motor Induksi AC",
    "daya_kW": 15,
    "tegangan_V": 380,
    "rpm": 1450
}

# Cetak salah satu nilai lewat key-nya
print("Daya motor:", motor_listrik["daya_kW"], "kW")

# Ubah nilai rpm (pakai =)
motor_listrik["rpm"] = 1500

# Cetak ulang seluruh dictionary
print(motor_listrik)
# Out:
# Daya motor: 15 kW
# {'nama': 'Motor Induksi AC', 'daya_kW': 15, 'tegangan_V': 380, 'rpm': 1500}

# %%
# Jawaban Latihan 6
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80, "status": "pemeliharaan"},
]

# Cetak nama unit kedua
print("Nama unit kedua:", pembangkit[1]["nama"])

# Ubah status salah satu unit (misal Unit-3 jadi operasi)
pembangkit[2]["status"] = "operasi"

# Tambahkan satu unit baru ke list dengan append()
pembangkit.append({"nama": "Unit-4", "kapasitas_MW": 120, "status": "operasi"})

# Cetak seluruh data
print(pembangkit)
# Out:
# Nama unit kedua: Unit-2
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}, {'nama': 'Unit-4', 'kapasitas_MW': 120, 'status': 'operasi'}]
